# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load data
edges = pd.read_csv("../data/edge.csv", header=None)
feat_train = pd.read_csv("../data/node_feat_train.csv")
feat_val = pd.read_csv("../data/node_feat_valid.csv")
feat_test = pd.read_csv("../data/node_feat_test.csv")
year_train = pd.read_csv("../data/node_year_train.csv")
year_val = pd.read_csv("../data/node_year_valid.csv")
year_test = pd.read_csv("../data/node_year_test.csv")
label_train = pd.read_csv("../data/node_label_train.csv")
label_val = pd.read_csv("../data/node_label_valid.csv")

# %%
# dataset size
print('train: {}'.format(len(feat_train)))
print('valid: {}'.format(len(feat_val)))
print('test: {}'.format(len(feat_test)))
# Out:
# train: 90941
# valid: 29799
# test: 48603

# %%
# unique values of label
print(sorted(label_train['0'].unique()))
print(sorted(label_val['0'].unique()))
# Out:
# [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20), np.int64(21), np.int64(22), np.int64(23), np.int64(24), np.int64(25), np.int64(26), np.int64(27), np.int64(28), np.int64(29), np.int64(30), np.int64(31), np.int64(32), np.int64(33), np.int64(34), np.int64(35), np.int64(36), np.int64(37), np.int64(38), np.int64(39)]
# [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20), np.int64(21), np.int64(22), np.int64(23), np.int64(24), np.int64(25), np.int64(26), np.int64(27), np.int64(28), np.int64(29), np.int64(30), np.int64(31), np.int64(32), np.int64(33), np.int64(34), np.int64(35), np.int64(36), np.int64(37), np.int64(38), np.int64(39)]

# %%
# label distribution(train)
plt.figure(figsize=(12, 6))
sns.countplot(x='0', data=label_train, order=range(0, 40), palette='pastel')
plt.title('label distribution(train)')
plt.xlabel('label')
plt.ylabel('count')
plt.show()
# Out:
# /var/folders/d2/gh0v207s7wq0gn0ptj8jlx0r0000gn/T/ipykernel_92253/3591582141.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='0', data=label_train, order=range(0, 40), palette='pastel')

# %%
# label distribution(valid)
plt.figure(figsize=(12, 6))
sns.countplot(x='0', data=label_val, order=range(0, 40), palette='pastel')
plt.title('label distribution(valid)')
plt.xlabel('label')
plt.ylabel('count')
plt.show()
# Out:
# /var/folders/d2/gh0v207s7wq0gn0ptj8jlx0r0000gn/T/ipykernel_92253/1355567861.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='0', data=label_val, order=range(0, 40), palette='pastel')

# %%
# unique values of year
print(sorted(year_train['0'].unique()))
# Out:
# [np.int64(1971), np.int64(1986), np.int64(1987), np.int64(1988), np.int64(1990), np.int64(1991), np.int64(1992), np.int64(1993), np.int64(1994), np.int64(1995), np.int64(1996), np.int64(1997), np.int64(1998), np.int64(1999), np.int64(2000), np.int64(2001), np.int64(2002), np.int64(2003), np.int64(2004), np.int64(2005), np.int64(2006), np.int64(2007), np.int64(2008), np.int64(2009), np.int64(2010), np.int64(2011), np.int64(2012), np.int64(2013), np.int64(2014), np.int64(2015), np.int64(2016), np.int64(2017)]

# %%
# yearly distribution
plt.figure(figsize=(24, 8))
sns.countplot(x='0', data=year_train, order=range(1971, 2018), palette='pastel')
plt.title('yearly distribution')
plt.xlabel('year')
plt.ylabel('count')
plt.show()
# Out:
# /var/folders/d2/gh0v207s7wq0gn0ptj8jlx0r0000gn/T/ipykernel_92253/1409306189.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='0', data=year_train, order=range(1971, 2018), palette='pastel')

# %%
# degree distribution
plt.figure(figsize=(12, 6))
plt.hist(edges[0], bins=100, color='blue', alpha=0.7, label='Source')
plt.hist(edges[1], bins=100, color='red', alpha=0.5, label='Target')
plt.title('distribution of source and target nodes')
plt.xlabel('Node ID')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
years = pd.concat([year_train, year_val, year_test], axis=0).sort_values('id')
years
# Out:
#            id     0
# 0           0  2013
# 1           1  2015
# 2           2  2014
# 3           3  2014
# 4           4  2014
# ...       ...   ...
# 48598  169338  2020
# 48599  169339  2020
# 48600  169340  2020
# 48601  169341  2020
# 48602  169342  2020
#
# [169343 rows x 2 columns]

# %%
# data validation
years = pd.concat([year_train, year_val, year_test], axis=0).sort_values('id').values
id_year_map = {id: year for id, year in years}
edge_index = edges.values
mask = np.array([id_year_map[i] < id_year_map[j] for i, j in edge_index])
print(len(edge_index[mask]))
# Out:
# 20903

# %%
edges
# Out:
#               0       1
# 0        104447   13091
# 1         15858   47283
# 2        107156   69161
# 3        107156  136440
# 4        107156  107366
# ...         ...     ...
# 1166238   45118   79124
# 1166239   45118  147994
# 1166240   45118  162473
# 1166241   45118  162537
# 1166242   45118   72717
#
# [1166243 rows x 2 columns]
